# %% [markdown]
# # Introduction

# %%
print("Hello World")
# Out:
# Hello World

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
pd.DataFrame(
    {'values': np.random.randint(0, 100, 100)}
).plot()
# Out:
# <AxesSubplot:>
